# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\irbyh\anaconda3\lib\site-packages (2.8.3)

# %%
import os
import json
import pandas as pd
import numpy as np
import psycopg2
import psycopg2.extras
import sys

# %%
from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

# %%
app = Flask(__name__)

# %%
#################################################
# Database Setup
#################################################
conn_string = "host='localhost' dbname='500_cities' user='kgi' password='kgi'"
print ("Connecting to database\n    ->%s" % (conn_string))
# Out:
# Connecting to database
#     ->host='localhost' dbname='500_cities' user='kgi' password='kgi'

# %%
print ("Connecting to database\n    ->%s" % (conn_string))
# Out:
# Connecting to database
#     ->host='localhost' dbname='500_cities' user='kgi' password='kgi'

# %%
conn = psycopg2.connect(conn_string)

# %%
dict_cur = conn.cursor('cursor_unique_name', cursor_factory=psycopg2.extras.DictCursor)
dict_cur.execute('SELECT * FROM data')
rec= dict_cur.fetchall()
# print(rec[0])

# %%
rec
# Out:
# [[1,
#   1000,
#   1000,
#   0.037,
#   1.167,
#   4000,
#   4,
#   'string',
#   'string',
#   'string',
#   'string',
#   'string',
#   'string',
#   'number',
#   'string',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'number',
#   'string',
#   'string',
#   'date',
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   1302,
#   5171,
#   25.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   478,
#   1707,
#   28.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   4160,
#   15702,
#   26.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   1013,
#   3573,
#   28.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   4145,
#   16541,
#   25.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   2326,
#   7261,
#   32.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   8305,
#   32243,
#   25.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AK',
#   2,
#   3000,
#   203000,
#   'Anchorage',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   3186,
#   14531,
#   21.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   0,
#   62,
#   0.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   2190,
#   9532,
#   23.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1161,
#   5252,
#   22.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   28,
#   359,
#   7.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1089,
#   5163,
#   21.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   14,
#   75,
#   18.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   2250,
#   10415,
#   21.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   7000,
#   107000,
#   'Birmingham',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   18,
#   387,
#   4.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   72,
#   901,
#   8.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   328,
#   3370,
#   9.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   821,
#   7072,
#   11.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   119,
#   1519,
#   7.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   696,
#   7499,
#   9.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   61,
#   611,
#   10.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1517,
#   14571,
#   10.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   35896,
#   135896,
#   'Hoover',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   937,
#   8170,
#   11.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   42,
#   245,
#   17.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   1167,
#   3651,
#   32.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1210,
#   4597,
#   26.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   217,
#   858,
#   25.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1166,
#   4772,
#   24.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   154,
#   520,
#   29.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   2376,
#   9369,
#   25.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   37000,
#   137000,
#   'Huntsville',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   796,
#   4095,
#   19.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   40,
#   348,
#   11.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   2320,
#   11581,
#   20.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1473,
#   7648,
#   19.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   0,
#   396,
#   0.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1353,
#   7386,
#   18.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   23,
#   58,
#   39.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   2826,
#   15034,
#   18.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   50000,
#   150000,
#   'Mobile',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   443,
#   2651,
#   16.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   34,
#   990,
#   3.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   2946,
#   19046,
#   15.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1725,
#   12415,
#   13.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   98,
#   1555,
#   6.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1795,
#   12508,
#   14.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   42,
#   359,
#   11.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   3520,
#   24923,
#   14.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   51000,
#   151000,
#   'Montgomery',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   400,
#   2973,
#   13.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   16,
#   158,
#   10.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   811,
#   4216,
#   19.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   536,
#   3108,
#   17.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   20,
#   194,
#   10.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   517,
#   3221,
#   16.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   12,
#   51,
#   23.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1053,
#   6329,
#   16.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AL',
#   1,
#   77256,
#   177256,
#   'Tuscaloosa',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   194,
#   1710,
#   11.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   46,
#   456,
#   10.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   109,
#   921,
#   11.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   474,
#   4875,
#   9.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   115,
#   1182,
#   9.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   471,
#   5100,
#   9.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   103,
#   579,
#   17.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   945,
#   9975,
#   9.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   23290,
#   523290,
#   'Fayetteville',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   572,
#   6837,
#   8.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   38,
#   598,
#   6.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   218,
#   1021,
#   21.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   711,
#   4530,
#   15.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   362,
#   2818,
#   12.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   729,
#   4551,
#   16.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   200,
#   839,
#   23.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1440,
#   9081,
#   15.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   24550,
#   524550,
#   'Fort Smith',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   622,
#   3805,
#   16.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   20,
#   167,
#   12.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   899,
#   3885,
#   23.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1040,
#   5311,
#   19.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   194,
#   1050,
#   18.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1096,
#   5706,
#   19.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   78,
#   368,
#   21.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   2136,
#   11017,
#   19.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   35710,
#   535710,
#   'Jonesboro',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   945,
#   5547,
#   17.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   47,
#   739,
#   6.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   2482,
#   11258,
#   22.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1668,
#   9945,
#   16.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   412,
#   2249,
#   18.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1853,
#   9656,
#   19.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   45,
#   393,
#   11.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   3521,
#   19601,
#   18.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   41000,
#   541000,
#   'Little Rock',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   535,
#   4962,
#   10.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   126,
#   1109,
#   11.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   30,
#   256,
#   11.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   436,
#   4653,
#   9.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   342,
#   4015,
#   8.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   403,
#   4855,
#   8.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   22,
#   263,
#   8.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   839,
#   9508,
#   8.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AR',
#   5,
#   66080,
#   566080,
#   'Springdale',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   319,
#   3865,
#   8.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   49,
#   388,
#   12.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   371,
#   1772,
#   20.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1631,
#   7937,
#   20.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   2234,
#   10655,
#   21.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1650,
#   8238,
#   20.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   130,
#   607,
#   21.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   3281,
#   16175,
#   20.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   4720,
#   404720,
#   'Avondale',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   497,
#   2753,
#   18.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   359,
#   4584,
#   7.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   459,
#   2703,
#   17.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   2993,
#   20443,
#   14.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   1764,
#   10444,
#   16.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   2884,
#   20619,
#   14.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   456,
#   2468,
#   18.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   5877,
#   41062,
#   14.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   12000,
#   412000,
#   'Chandler',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   2839,
#   20863,
#   13.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   27400,
#   427400,
#   'Gilbert',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   186,
#   2278,
#   8.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   27400,
#   427400,
#   'Gilbert',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   242,
#   1763,
#   13.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'AZ',
#   4,
#   27400,
#   427400,
#   'Gilbert',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   2885,
#   21736,
#   13.3,
# ...
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   841,
#   6635,
#   12.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   858,
#   4687,
#   18.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   977,
#   6995,
#   14.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   100,
#   790,
#   12.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1818,
#   13630,
#   13.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69084,
#   669084,
#   'Santa Clara',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   366,
#   2885,
#   12.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   205,
#   2853,
#   7.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   171,
#   1237,
#   13.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1976,
#   15553,
#   12.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   1847,
#   14414,
#   12.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   2069,
#   16829,
#   12.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   165,
#   1288,
#   12.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   4045,
#   32382,
#   12.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69088,
#   669088,
#   'Santa Clarita',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   1657,
#   12590,
#   13.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   30,
#   437,
#   6.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   27,
#   100,
#   27.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   713,
#   6631,
#   10.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   1235,
#   11898,
#   10.4,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   684,
#   6723,
#   10.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   16,
#   91,
#   17.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1397,
#   13354,
#   10.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   69196,
#   669196,
#   'Santa Maria',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   89,
#   828,
#   10.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   39,
#   436,
#   8.9,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   87,
#   496,
#   17.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   596,
#   3180,
#   18.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   466,
#   2314,
#   20.1,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   546,
#   3357,
#   16.3,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   78,
#   467,
#   16.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   1142,
#   6537,
#   17.5,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70000,
#   670000,
#   'Santa Monica',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   472,
#   2824,
#   16.7,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'asian',
#   4,
#   152,
#   1582,
#   9.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'black',
#   5,
#   100,
#   537,
#   18.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'female',
#   2,
#   1848,
#   11515,
#   16.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'hispanic',
#   6,
#   1888,
#   11126,
#   17.0,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'male',
#   3,
#   1792,
#   11827,
#   15.2,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'other',
#   8,
#   281,
#   1290,
#   21.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'total population',
#   1,
#   3640,
#   23342,
#   15.6,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z'],
#  [None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   'CA',
#   6,
#   70098,
#   670098,
#   'Santa Rosa',
#   'Absenteeism',
#   1,
#   'white',
#   7,
#   1219,
#   8807,
#   13.8,
#   -999,
#   -999,
#   -999,
#   -999,
#   -999,
#   '2015-2016',
#   'city',
#   '2019-06-11T00:00:00Z']]
